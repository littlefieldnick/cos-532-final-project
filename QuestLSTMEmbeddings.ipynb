# %%
import os
import pandas as pd
import numpy as np

import torch
from  torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext import vocab, data
from torchtext.data import TabularDataset, BucketIterator
from torch.utils.data import DataLoader
import gensim
from nltk.tokenize import TreebankWordTokenizer
from spacy.tokenizer import Tokenizer
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
DATA_PTH = "data/"
TRAIN = "train_processed.csv"
TEST = "test_processed.csv"
EMB_FILE = "embeddings_processed.txt"
BATCH_SIZE = 128
EPOCHS = 15
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# word2vec Params
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 150
W2V_MIN_COUNT = 2

# %%
target_question_columns = [
       'question_asker_intent_understanding',
       'question_body_critical', 'question_conversational',
       'question_expect_short_answer', 'question_fact_seeking',
       'question_has_commonly_accepted_answer',
       'question_interestingness_others', 'question_interestingness_self',
       'question_multi_intent', 'question_not_really_a_question',
       'question_opinion_seeking', 'question_type_choice',
       'question_type_compare', 'question_type_consequence',
       'question_type_definition', 'question_type_entity',
       'question_type_instructions', 'question_type_procedure',
       'question_type_reason_explanation', 'question_type_spelling',
       'question_well_written'
]
    
target_answer_columns = [
       'answer_helpful',
       'answer_level_of_information', 'answer_plausible', 'answer_relevance',
       'answer_satisfaction', 'answer_type_instructions',
       'answer_type_procedure', 'answer_type_reason_explanation',
       'answer_well_written'
]

# %%
def define_torchtext_fields():
    tokenizer=TreebankWordTokenizer().tokenize
    text_field = data.Field(sequential=True, tokenize=tokenizer, use_vocab=True,
                           batch_first=True, include_lengths=False)
    num_field = data.Field(sequential=False, dtype=torch.float, use_vocab=False)
    index_field = data.Field(sequential=False, dtype=torch.int, use_vocab=False)
#     raw_field = data.RawField()
    
    return text_field, num_field, index_field #, raw_field

# %%
def build_w2v_documents(pth_to_train, columns, tokenizer):
    train = pd.read_csv(pth_to_train, usecols=columns)
    documents = []
    for col in columns:
        documents = documents + [tokenizer.tokenize(text) for text in train[col]]

    return documents

def build_w2v_model(pth_to_train, columns, save_embeddings=False):
    docs = build_w2v_documents(pth_to_train, columns, TreebankWordTokenizer())

    # Train Word Embeddings and save
    w2v = gensim.models.word2vec.Word2Vec(size=W2V_SIZE, 
                                          window=W2V_WINDOW,                                                                                  
                                          min_count=W2V_MIN_COUNT)
    w2v.build_vocab(docs)
    words = w2v.wv.vocab.keys()
    vocab_size = len(words)
    print("Vocab size", vocab_size)

    # Train Word Embeddings
    w2v.train(docs, total_examples=len(docs), epochs=W2V_EPOCH)
    
    if save_embeddings:
        w2v.save(DATA_PTH + EMB_FILE)

    return w2v

# %%
def prepare_dataset():
    if os.path.exists(DATA_PTH + EMB_FILE):
        w2v_model = gensim.models.Word2Vec.load(DATA_PTH + EMB_FILE)
    else:
        w2v_model = build_w2v_model(DATA_PTH + TRAIN, 
                                   ["text"], 
                                   save_embeddings=True)
    
    txt, num, idx = define_torchtext_fields()

    predictor_columns = [
        ('qa_id', idx),
        ('text', txt),
#         ('question_body', txt),
#         ('question_user_name', raw),
#         ('question_user_page', raw),
#         ('answer', txt),
#         ('answer_user_name', raw),
#         ('answer_user_page', raw),
#         ('url', raw),
#         ('category', raw),
#         ('host', raw)
    ]
  
    
    targets = pd.read_csv(DATA_PTH + TRAIN).columns[2:]
    targets =  list(zip(targets, [num]*len(targets)))
    print(targets)
    train_val_cols = predictor_columns + targets
    test_cols = predictor_columns
    
    train_ds, valid_ds = TabularDataset(DATA_PTH + TRAIN, 
                                        format="csv", 
                                        fields=train_val_cols, skip_header=True).split(split_ratio=0.7)
    test_ds = TabularDataset(DATA_PTH + TEST, format="csv", skip_header=True, fields=test_cols)
    
    txt.build_vocab(train_ds, valid_ds, min_freq=W2V_MIN_COUNT)
    word2vec_vectors = []
    for token, idx in txt.vocab.stoi.items():
        if token in w2v_model.wv.vocab.keys():
            word2vec_vectors.append(torch.FloatTensor(w2v_model[token]))
        else:
            word2vec_vectors.append(torch.zeros(W2V_SIZE))
    txt.vocab.set_vectors(txt.vocab.stoi, word2vec_vectors, W2V_SIZE)
    
    return train_ds, valid_ds, test_ds, txt

# %%
train_ds, valid_ds, test_ds, vocab = prepare_dataset()
# Out:
# [('question_asker_intent_understanding', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_body_critical', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_conversational', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_expect_short_answer', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_fact_seeking', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_has_commonly_accepted_answer', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_interestingness_others', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_interestingness_self', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_multi_intent', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_not_really_a_question', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_opinion_seeking', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_choice', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_compare', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_consequence', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_definition', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_entity', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_instructions', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_procedure', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_reason_explanation', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_type_spelling', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('question_well_written', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_helpful', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_level_of_information', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_plausible', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_relevance', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_satisfaction', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_type_instructions', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_type_procedure', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_type_reason_explanation', <torchtext.data.field.Field object at 0x7fce37b2ef98>), ('answer_well_written', <torchtext.data.field.Field object at 0x7fce37b2ef98>)]

# %%
len(train_ds), len(valid_ds), len(test_ds), len(vocab.vocab.stoi)
# Out:
# (4255, 1824, 476, 40072)

# %%
vocab.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x7fce37b2ed68>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              'the': 2,
#              'to': 3,
#              'a': 4,
#              'i': 5,
#              'is': 6,
#              'and': 7,
#              'of': 8,
#              '&': 9,
#              'in': 10,
#              'it': 11,
#              'that': 12,
#              'you': 13,
#              'not': 14,
#              'for': 15,
#              'this': 16,
#              'have': 17,
#              'on': 18,
#              'be': 19,
#              'with': 20,
#              'can': 21,
#              'are': 22,
#              'if': 23,
#              'gt': 24,
#              'as': 25,
#              'but': 26,
#              'or': 27,
#              's': 28,
#              'do': 29,
#              'my': 30,
#              'from': 31,
#              'an': 32,
#              'will': 33,
#              'so': 34,
#              'would': 35,
#              'at': 36,
#              'your': 37,
#              'there': 38,
#              'am': 39,
#              'what': 40,
#              'how': 41,
#              'by': 42,
#              'lt': 43,
#              'one': 44,
#              'use': 45,
#              'which': 46,
#              '1': 47,
#              'when': 48,
#              'like': 49,
#              'all': 50,
#              'some': 51,
#              'then': 52,
#              'they': 53,
#              'any': 54,
#              'get': 55,
#              'using': 56,
#              'does': 57,
#              'was': 58,
#              'just': 59,
#              'more': 60,
#              'has': 61,
#              '0': 62,
#              'should': 63,
#              'we': 64,
#              'want': 65,
#              'other': 66,
#              'need': 67,
#              'only': 68,
#              '2': 69,
#              'no': 70,
#              'way': 71,
#              'about': 72,
#              'also': 73,
#              'up': 74,
#              'time': 75,
#              'new': 76,
#              'could': 77,
#              'out': 78,
#              'code': 79,
#              'me': 80,
#              'where': 81,
#              'here': 82,
#              'them': 83,
#              'same': 84,
#              'make': 85,
#              'than': 86,
#              'file': 87,
#              'know': 88,
#              'into': 89,
#              'work': 90,
#              'two': 91,
#              'set': 92,
#              'see': 93,
#              'data': 94,
#              'because': 95,
#              'first': 96,
#              'amp': 97,
#              'question': 98,
#              'example': 99,
#              'now': 100,
#              'these': 101,
#              'used': 102,
#              'after': 103,
#              'their': 104,
#              'find': 105,
#              'why': 106,
#              'he': 107,
#              'function': 108,
#              'problem': 109,
#              'something': 110,
#              'even': 111,
#              'x': 112,
#              'good': 113,
#              '3': 114,
#              'very': 115,
#              'http': 116,
#              'each': 117,
#              'may': 118,
#              'user': 119,
#              'been': 120,
#              'page': 121,
#              'think': 122,
#              'different': 123,
#              'return': 124,
#              'server': 125,
#              'c': 126,
#              'such': 127,
#              'class': 128,
#              'much': 129,
#              'most': 130,
#              'right': 131,
#              'its': 132,
#              'add': 133,
#              'name': 134,
#              'since': 135,
#              'another': 136,
#              'however': 137,
#              'value': 138,
#              'go': 139,
#              'still': 140,
#              'end': 141,
#              'list': 142,
#              'did': 143,
#              'case': 144,
#              'between': 145,
#              'error': 146,
#              'number': 147,
#              'help': 148,
#              'had': 149,
#              'well': 150,
#              'might': 151,
#              'public': 152,
#              'try': 153,
#              'system': 154,
#              'possible': 155,
#              'while': 156,
#              'create': 157,
#              'following': 158,
#              'before': 159,
#              'many': 160,
#              'without': 161,
#              'line': 162,
#              'etc': 163,
#              'really': 164,
#              'say': 165,
#              '4': 166,
#              'answer': 167,
#              'being': 168,
#              'change': 169,
#              'take': 170,
#              'through': 171,
#              'over': 172,
#              'both': 173,
#              'b': 174,
#              'string': 175,
#              'people': 176,
#              '10': 177,
#              'image': 178,
#              'who': 179,
#              'n': 180,
#              'text': 181,
#              'point': 182,
#              'were': 183,
#              'run': 184,
#              'type': 185,
#              'back': 186,
#              'better': 187,
#              'trying': 188,
#              'table': 189,
#              'look': 190,
#              'too': 191,
#              'int': 192,
#              'files': 193,
#              'else': 194,
#              'able': 195,
#              'sure': 196,
#              '5': 197,
#              'field': 198,
#              'off': 199,
#              'key': 200,
#              'start': 201,
#              'going': 202,
#              'bit': 203,
#              'seems': 204,
#              'every': 205,
#              'current': 206,
#              'things': 207,
#              'found': 208,
#              'method': 209,
#              'his': 210,
#              'read': 211,
#              'down': 212,
#              'those': 213,
#              'edit': 214,
#              'looking': 215,
#              'site': 216,
#              'array': 217,
#              'part': 218,
#              'y': 219,
#              'let': 220,
#              'application': 221,
#              'size': 222,
#              'best': 223,
#              'access': 224,
#              'update': 225,
#              'long': 226,
#              'works': 227,
#              'select': 228,
#              'id': 229,
#              'output': 230,
#              'lot': 231,
#              'our': 232,
#              'instead': 233,
#              'working': 234,
#              'object': 235,
#              'actually': 236,
#              'check': 237,
#              'running': 238,
#              'f': 239,
#              'information': 240,
#              'order': 241,
#              'though': 242,
#              'form': 243,
#              'd': 244,
#              'true': 245,
#              'thanks': 246,
#              'left': 247,
#              't': 248,
#              'above': 249,
#              'second': 250,
#              'version': 251,
#              'show': 252,
#              'give': 253,
#              'windows': 254,
#              'tried': 255,
#              'own': 256,
#              'put': 257,
#              'e': 258,
#              'solution': 259,
#              'var': 260,
#              'around': 261,
#              'less': 262,
#              'script': 263,
#              'simple': 264,
#              'app': 265,
#              'source': 266,
#              'always': 267,
#              'p': 268,
#              'done': 269,
#              'having': 270,
#              'again': 271,
#              'post': 272,
#              'word': 273,
#              'already': 274,
#              'based': 275,
#              'thing': 276,
#              'either': 277,
#              'probably': 278,
#              'doing': 279,
#              'database': 280,
#              'values': 281,
#              'result': 282,
#              'must': 283,
#              'given': 284,
#              'power': 285,
#              'few': 286,
#              'last': 287,
#              'call': 288,
#              'never': 289,
#              'view': 290,
#              'group': 291,
#              'means': 292,
#              'r': 293,
#              'open': 294,
#              'level': 295,
#              'non': 296,
#              'game': 297,
#              'null': 298,
#              'note': 299,
#              'understand': 300,
#              'specific': 301,
#              'questions': 302,
#              'option': 303,
#              'issue': 304,
#              'write': 305,
#              'users': 306,
#              'command': 307,
#              'times': 308,
#              '6': 309,
#              'correct': 310,
#              'high': 311,
#              '8': 312,
#              'please': 313,
#              'idea': 314,
#              'enough': 315,
#              'ie': 316,
#              'mean': 317,
#              'top': 318,
#              'anyone': 319,
#              'least': 320,
#              'someone': 321,
#              'web': 322,
#              '7': 323,
#              'link': 324,
#              'single': 325,
#              'small': 326,
#              'input': 327,
#              'next': 328,
#              'eg': 329,
#              'anything': 330,
#              'content': 331,
#              'getting': 332,
#              'made': 333,
#              'got': 334,
#              'called': 335,
#              'below': 336,
#              'once': 337,
#              'query': 338,
#              'us': 339,
#              'message': 340,
#              'similar': 341,
#              'keep': 342,
#              'far': 343,
#              'install': 344,
#              'said': 345,
#              'default': 346,
#              'difference': 347,
#              'space': 348,
#              'project': 349,
#              'reason': 350,
#              'network': 351,
#              'side': 352,
#              'button': 353,
#              'service': 354,
#              'simply': 355,
#              'process': 356,
#              'device': 357,
#              'm': 358,
#              'test': 359,
#              'main': 360,
#              'wrong': 361,
#              'multiple': 362,
#              'often': 363,
#              'little': 364,
#              'quite': 365,
#              'old': 366,
#              'usually': 367,
#              'tell': 368,
#              'kind': 369,
#              'google': 370,
#              'images': 371,
#              'fine': 372,
#              'hard': 373,
#              'course': 374,
#              'voltage': 375,
#              'static': 376,
#              'makes': 377,
#              'void': 378,
#              'custom': 379,
#              'path': 380,
#              'remove': 381,
#              'available': 382,
#              'created': 383,
#              'under': 384,
#              'per': 385,
#              'place': 386,
#              'title': 387,
#              'maybe': 388,
#              'points': 389,
#              'state': 390,
#              'print': 391,
#              'machine': 392,
#              'nbsp': 393,
#              'column': 394,
#              'general': 395,
#              'home': 396,
#              'real': 397,
#              'bad': 398,
#              'rather': 399,
#              'sql': 400,
#              'display': 401,
#              'local': 402,
#              'results': 403,
#              'click': 404,
#              'url': 405,
#              'book': 406,
#              'full': 407,
#              'player': 408,
#              '100': 409,
#              'original': 410,
#              'whether': 411,
#              'false': 412,
#              'save': 413,
#              'via': 414,
#              'making': 415,
#              'seem': 416,
#              'standard': 417,
#              'address': 418,
#              'large': 419,
#              'fact': 420,
#              'computer': 421,
#              'html': 422,
#              'product': 423,
#              'control': 424,
#              'free': 425,
#              'k': 426,
#              'him': 427,
#              'likely': 428,
#              'reference': 429,
#              'common': 430,
#              'inside': 431,
#              'words': 432,
#              'options': 433,
#              'model': 434,
#              'looks': 435,
#              'search': 436,
#              'come': 437,
#              'energy': 438,
#              'within': 439,
#              'drive': 440,
#              'three': 441,
#              'water': 442,
#              'certain': 443,
#              'instance': 444,
#              'sense': 445,
#              'map': 446,
#              'load': 447,
#              'particular': 448,
#              'consider': 449,
#              'email': 450,
#              'ltphp': 451,
#              'memory': 452,
#              'says': 453,
#              'everything': 454,
#              'private': 455,
#              'low': 456,
#              'person': 457,
#              'date': 458,
#              'php': 459,
#              'until': 460,
#              '20': 461,
#              'allow': 462,
#              'color': 463,
#              'include': 464,
#              'block': 465,
#              'design': 466,
#              'uses': 467,
#              'whole': 468,
#              'pretty': 469,
#              'years': 470,
#              'easy': 471,
#              'several': 472,
#              'lines': 473,
#              'element': 474,
#              'her': 475,
#              'settings': 476,
#              'store': 477,
#              'changes': 478,
#              'echo': 479,
#              'yet': 480,
#              'java': 481,
#              'she': 482,
#              'ubuntu': 483,
#              'client': 484,
#              'security': 485,
#              'log': 486,
#              'mode': 487,
#              'program': 488,
#              '12': 489,
#              'needs': 490,
#              'package': 491,
#              'world': 492,
#              'exactly': 493,
#              'items': 494,
#              'div': 495,
#              'domain': 496,
#              'item': 497,
#              'g': 498,
#              'play': 499,
#              'required': 500,
#              'yes': 501,
#              'light': 502,
#              'move': 503,
#              'software': 504,
#              'window': 505,
#              'account': 506,
#              'gets': 507,
#              'password': 508,
#              'linux': 509,
#              'important': 510,
#              'clear': 511,
#              'during': 512,
#              'nothing': 513,
#              'day': 514,
#              'event': 515,
#              'numbers': 516,
#              'great': 517,
#              'import': 518,
#              'javascript': 519,
#              'related': 520,
#              'sort': 521,
#              'connection': 522,
#              'paper': 523,
#              'screen': 524,
#              'students': 525,
#              'background': 526,
#              'mail': 527,
#              'send': 528,
#              'objects': 529,
#              'big': 530,
#              'variable': 531,
#              'ask': 532,
#              'format': 533,
#              'hand': 534,
#              'seen': 535,
#              'short': 536,
#              'directory': 537,
#              'setting': 538,
#              'character': 539,
#              'itself': 540,
#              'close': 541,
#              'term': 542,
#              'normal': 543,
#              'force': 544,
#              'lta': 545,
#              'switch': 546,
#              'thought': 547,
#              'circuit': 548,
#              'against': 549,
#              'build': 550,
#              'card': 551,
#              'effect': 552,
#              'hit': 553,
#              'reading': 554,
#              'dev': 555,
#              'box': 556,
#              'sometimes': 557,
#              'currently': 558,
#              'disk': 559,
#              'god': 560,
#              'range': 561,
#              'filter': 562,
#              'index': 563,
#              'node': 564,
#              'added': 565,
#              'comes': 566,
#              '11': 567,
#              'due': 568,
#              'functions': 569,
#              'problems': 570,
#              'final': 571,
#              'language': 572,
#              'others': 573,
#              'takes': 574,
#              'loop': 575,
#              'support': 576,
#              'menu': 577,
#              'rules': 578,
#              'turn': 579,
#              'car': 580,
#              'style': 581,
#              'length': 582,
#              'english': 583,
#              'h': 584,
#              'folder': 585,
#              'position': 586,
#              'answers': 587,
#              'figure': 588,
#              'job': 589,
#              'l': 590,
#              'later': 591,
#              'year': 592,
#              '9': 593,
#              'adding': 594,
#              'basic': 595,
#              'body': 596,
#              'days': 597,
#              'meaning': 598,
#              'ltdiv': 599,
#              'methods': 600,
#              'pages': 601,
#              'comment': 602,
#              'python': 603,
#              'although': 604,
#              'fields': 605,
#              'z': 606,
#              'matter': 607,
#              'amount': 608,
#              'company': 609,
#              'api': 610,
#              'bytes': 611,
#              'library': 612,
#              'thus': 613,
#              'website': 614,
#              'needed': 615,
#              'stop': 616,
#              'attack': 617,
#              'directly': 618,
#              'bottom': 619,
#              'document': 620,
#              'especially': 621,
#              'action': 622,
#              'copy': 623,
#              'fix': 624,
#              'os': 625,
#              'provide': 626,
#              'area': 627,
#              'assume': 628,
#              'gives': 629,
#              'away': 630,
#              'ok': 631,
#              'therefore': 632,
#              'installed': 633,
#              'elements': 634,
#              'ip': 635,
#              'row': 636,
#              'delete': 637,
#              'speed': 638,
#              'approach': 639,
#              'stack': 640,
#              'connected': 641,
#              'examples': 642,
#              'shows': 643,
#              'session': 644,
#              'white': 645,
#              '15': 646,
#              'properties': 647,
#              'stuff': 648,
#              'head': 649,
#              'creating': 650,
#              'experience': 651,
#              'terms': 652,
#              'cause': 653,
#              'feel': 654,
#              'pass': 655,
#              'across': 656,
#              'android': 657,
#              'zero': 658,
#              'front': 659,
#              'goes': 660,
#              'q': 661,
#              'signal': 662,
#              'sound': 663,
#              'ways': 664,
#              'research': 665,
#              'according': 666,
#              'choose': 667,
#              'completely': 668,
#              'engine': 669,
#              'useful': 670,
#              'vector': 671,
#              'complete': 672,
#              'total': 673,
#              'v': 674,
#              'insert': 675,
#              'remember': 676,
#              'cases': 677,
#              'basically': 678,
#              'root': 679,
#              'whatever': 680,
#              'defined': 681,
#              'links': 682,
#              'revision': 683,
#              'apply': 684,
#              'port': 685,
#              'connect': 686,
#              'higher': 687,
#              'started': 688,
#              'money': 689,
#              'perhaps': 690,
#              'property': 691,
#              'response': 692,
#              'longer': 693,
#              'none': 694,
#              'rest': 695,
#              'article': 696,
#              'camera': 697,
#              'context': 698,
#              'performance': 699,
#              'guess': 700,
#              'known': 701,
#              'thinking': 702,
#              'rule': 703,
#              'actual': 704,
#              'comments': 705,
#              'section': 706,
#              'count': 707,
#              'replace': 708,
#              '30': 709,
#              'changed': 710,
#              'pi': 711,
#              'starting': 712,
#              'allows': 713,
#              'generally': 714,
#              'hash': 715,
#              'missing': 716,
#              'step': 717,
#              'manager': 718,
#              'module': 719,
#              'css': 720,
#              'buy': 721,
#              'black': 722,
#              'contains': 723,
#              'sudo': 724,
#              'configuration': 725,
#              'o': 726,
#              'mysql': 727,
#              'request': 728,
#              'damage': 729,
#              'handle': 730,
#              're': 731,
#              'unless': 732,
#              'define': 733,
#              'feature': 734,
#              'hope': 735,
#              'browser': 736,
#              'https': 737,
#              'tool': 738,
#              'vs': 739,
#              'avoid': 740,
#              'extra': 741,
#              'online': 742,
#              'lens': 743,
#              'setup': 744,
#              'believe': 745,
#              'customer': 746,
#              'happens': 747,
#              'info': 748,
#              'require': 749,
#              'category': 750,
#              'selected': 751,
#              'special': 752,
#              'suggest': 753,
#              'wondering': 754,
#              'business': 755,
#              'cost': 756,
#              'parts': 757,
#              'theory': 758,
#              'issues': 759,
#              'label': 760,
#              'mind': 761,
#              'programming': 762,
#              'solve': 763,
#              'easier': 764,
#              'template': 765,
#              'width': 766,
#              'present': 767,
#              'easily': 768,
#              'existing': 769,
#              'explain': 770,
#              'further': 771,
#              'otherwise': 772,
#              'outside': 773,
#              'random': 774,
#              'almost': 775,
#              'choice': 776,
#              'frame': 777,
#              '2013': 778,
#              'asked': 779,
#              'desktop': 780,
#              'playing': 781,
#              'depends': 782,
#              'double': 783,
#              'games': 784,
#              'break': 785,
#              'languages': 786,
#              'law': 787,
#              'minutes': 788,
#              'players': 789,
#              'xml': 790,
#              'distance': 791,
#              'follow': 792,
#              'written': 793,
#              'books': 794,
#              'ones': 795,
#              'rate': 796,
#              'room': 797,
#              'usr': 798,
#              'applications': 799,
#              'live': 800,
#              'boot': 801,
#              'child': 802,
#              'couple': 803,
#              'price': 804,
#              'writing': 805,
#              '50': 806,
#              'devices': 807,
#              'statement': 808,
#              'variables': 809,
#              'classes': 810,
#              'various': 811,
#              'asking': 812,
#              'contain': 813,
#              'happen': 814,
#              'jquery': 815,
#              'recently': 816,
#              'correctly': 817,
#              'j': 818,
#              'returns': 819,
#              'battery': 820,
#              'bike': 821,
#              'environment': 822,
#              'ideas': 823,
#              'tree': 824,
#              'along': 825,
#              'situation': 826,
#              'assuming': 827,
#              'base': 828,
#              'def': 829,
#              'red': 830,
#              'self': 831,
#              'separate': 832,
#              '24': 833,
#              'details': 834,
#              'changing': 835,
#              'empty': 836,
#              'location': 837,
#              'types': 838,
#              'plugin': 839,
#              'thread': 840,
#              'wanted': 841,
#              'depending': 842,
#              'determine': 843,
#              'expect': 844,
#              'future': 845,
#              'house': 846,
#              'phone': 847,
#              'names': 848,
#              'probability': 849,
#              'bin': 850,
#              'download': 851,
#              'exception': 852,
#              'login': 853,
#              'share': 854,
#              'structure': 855,
#              'columns': 856,
#              'draw': 857,
#              'mentioned': 858,
#              'series': 859,
#              'previous': 860,
#              'task': 861,
#              'came': 862,
#              'interface': 863,
#              'limit': 864,
#              'status': 865,
#              'usb': 866,
#              'volume': 867,
#              'fixed': 868,
#              'life': 869,
#              'sites': 870,
#              'specifically': 871,
#              'bar': 872,
#              'including': 873,
#              'taking': 874,
#              'layer': 875,
#              'additional': 876,
#              'automatically': 877,
#              'considered': 878,
#              'host': 879,
#              'tag': 880,
#              'ever': 881,
#              'necessary': 882,
#              'together': 883,
#              '08': 884,
#              'half': 885,
#              'obviously': 886,
#              'positive': 887,
#              'profile': 888,
#              'seconds': 889,
#              'definition': 890,
#              'font': 891,
#              'appears': 892,
#              'match': 893,
#              'ms': 894,
#              'core': 895,
#              'entire': 896,
#              'mac': 897,
#              'negative': 898,
#              'packages': 899,
#              'sounds': 900,
#              'verified': 901,
#              'earth': 902,
#              'keys': 903,
#              'deal': 904,
#              'failed': 905,
#              'internet': 906,
#              'systems': 907,
#              'cards': 908,
#              'larger': 909,
#              'learn': 910,
#              'oil': 911,
#              'primary': 912,
#              'quantal': 913,
#              'sub': 914,
#              'appear': 915,
#              'description': 916,
#              'documentation': 917,
#              'ground': 918,
#              'moving': 919,
#              'sentence': 920,
#              'td': 921,
#              'equivalent': 922,
#              'except': 923,
#              'recommend': 924,
#              'building': 925,
#              'charge': 926,
#              'expected': 927,
#              'mass': 928,
#              'supply': 929,
#              '512': 930,
#              'chain': 931,
#              'join': 932,
#              'w': 933,
#              'advance': 934,
#              'hold': 935,
#              'kernel': 936,
#              'past': 937,
#              'pattern': 938,
#              'pc': 939,
#              'suppose': 940,
#              'exist': 941,
#              'become': 942,
#              'height': 943,
#              'regular': 944,
#              'shown': 945,
#              'today': 946,
#              'username': 947,
#              '200': 948,
#              'logic': 949,
#              'stored': 950,
#              'terminal': 951,
#              'center': 952,
#              'counter': 953,
#              'difficult': 954,
#              'generate': 955,
#              'requires': 956,
#              'finally': 957,
#              'fit': 958,
#              'potential': 959,
#              'records': 960,
#              'air': 961,
#              'enter': 962,
#              'exact': 963,
#              'override': 964,
#              'picture': 965,
#              'leave': 966,
#              'lower': 967,
#              'taken': 968,
#              'third': 969,
#              'admin': 970,
#              'appreciated': 971,
#              'built': 972,
#              'distribution': 973,
#              'faster': 974,
#              'messages': 975,
#              'prevent': 976,
#              'properly': 977,
#              'usage': 978,
#              '00': 979,
#              'algorithm': 980,
#              'controller': 981,
#              'debug': 982,
#              'active': 983,
#              'characters': 984,
#              'groups': 985,
#              'implement': 986,
#              'nice': 987,
#              'slow': 988,
#              'student': 989,
#              'direction': 990,
#              'follows': 991,
#              'json': 992,
#              'laptop': 993,
#              'tools': 994,
#              'features': 995,
#              'posts': 996,
#              'router': 997,
#              'argument': 998,
#              'complex': 999,
#              ...})

# %%
train_dl = BucketIterator(train_ds, 
                          batch_size=4, shuffle=True,
                          sort_key=lambda x: len(x.text))

# %%
valid_dl = BucketIterator(valid_ds, 
                          batch_size=4, shuffle=True,
                          sort_key=lambda x: len(x.text))

# %%
test_dl = BucketIterator(test_ds, batch_size=4, shuffle=False, sort_key=lambda x: len(x.text))

# %%
batch = next(iter(train_dl))
len(batch.text[0])
# Out:
# 906

# %%
class LSTMEmbedding(nn.Module):
    def __init__(self, embedding, output_size, hidden_size=128, num_layers=3, dropout=0.3, bidir=False):
        super(LSTMEmbedding, self).__init__()
        self.bidirectional = bidir
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.emb = nn.Embedding.from_pretrained(torch.FloatTensor(embedding), padding_idx=1, freeze=True)
#         self.qtitle_lstm = nn.LSTM(embedding.size(1), hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidir,
#                             dropout=dropout, batch_first=True)
        self.lstm = nn.LSTM(embedding.size(1), hidden_size=hidden_size, num_layers=num_layers, bidirectional=bidir,
                            dropout=dropout, batch_first=True)

        self.lstm2 = nn.LSTM(self.hidden_size*2, hidden_size=self.hidden_size, num_layers=num_layers, bidirectional=bidir,
                            dropout=dropout, batch_first=True)
       
        self.dropout = nn.Dropout(dropout)
        if bidir:
            self.linear_in = hidden_size*2
        else:
            self.linear_in = hidden_size
        self.classifier = nn.Sequential(nn.Linear(self.linear_in, 64),
                                        nn.ReLU(),
                                        nn.Linear(64, output_size))
    
    def forward(self, x):
        emb = self.emb(x)
        
        out, hid = self.lstm(emb)
        out, hid = self.lstm2(out, hid)        
        out = self.dropout(out)
        out = self.classifier(out)
        return torch.sigmoid(out)[:,-1,:]

# %%
model = LSTMEmbedding(vocab.vocab.vectors, 30, num_layers=1
                      , hidden_size=1024, bidir=True)

# %%
def print_epoch_results(epoch, tl, vl, spear_t, spear_v):
    if epoch == 1:
        print("\tTrain\t\tValidation")
        print("Epoch | Loss | Spear. | Loss | Spear.")
    
    raw_line = '{:6d}' + '\u2502{:6.3f}' * 4
    print(raw_line.format(epoch, tl, spear_t, vl, spear_v))

# %%
def spearman_correlation_metric(predicted, true):
    score = 0.
    for i in range(predicted.shape[1]):
        score += np.nan_to_num(spearmanr(predicted[:, i], true[:,i])[0])
    
    return score / 30

# %%
def get_target_tensor(batch):
    return torch.stack([getattr(batch, label) for label in target_question_columns +  target_answer_columns], dim=-1).cuda()

# %%
def train(model, train_loader, valid_loader, learning_rate, epochs):
    optimizer = torch.optim.Adam(model.parameters(), learning_rate)
    criterion = torch.nn.BCELoss()
    print("Starting training of model...")
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = []
        valid_loss = []
        train_spearman = []
        valid_spearman = []
        
        for batch in train_loader:
            optimizer.zero_grad()
            targets = get_target_tensor(batch)
            
            out = model(batch.text.to(DEVICE))
            loss = criterion(out, targets)
            train_loss.append(loss.item())
            train_spearman.append(spearman_correlation_metric(out.detach().cpu().numpy(),
                                                             targets.detach().cpu().numpy()))
            loss.backward()
            optimizer.step()
    
        model.eval()
        for batch in valid_loader:
            targets = get_target_tensor(batch)
            out = model(batch.text.to(DEVICE))
            loss = criterion(out, targets)
            valid_spearman.append(spearman_correlation_metric(out.detach().cpu().numpy(),
                                                             targets.detach().cpu().numpy()))
            valid_loss.append(loss.item())
            
        print_epoch_results(epoch, np.array(train_loss).mean(), np.array(valid_loss).mean(), np.array(train_spearman).mean(),
                            np.array(valid_spearman).mean())

# %%
train(model.cuda(), train_dl, valid_dl, 0.00025, 15)
# Out:
# Starting training of model...
# 	Train		Validation
# Epoch | Loss | Spear. | Loss | Spear.
#      1│ 0.415│ 0.142│ 0.398│ 0.194
#      2│ 0.391│ 0.218│ 0.389│ 0.210
#      3│ 0.376│ 0.259│ 0.387│ 0.225
#      4│ 0.362│ 0.308│ 0.387│ 0.228
#      5│ 0.349│ 0.343│ 0.392│ 0.228
#      6│ 0.336│ 0.376│ 0.396│ 0.227

# %%
torch.save(model, "models/lstm-15ep-lr0-01-hl-1024-bidir")

# %%
test_ids = []
test_preds = []
for batch in test_dl:
    out = model(batch.text.to(DEVICE))
    test_ids.extend(batch.qa_id.tolist())
    test_preds.extend(torch.sigmoid(out).detach().cpu().numpy())

# %%
ids = pd.DataFrame({"qa_id": test_ids})

# %%
preds = pd.DataFrame(np.round(test_preds, 5))
preds.columns = target_question_columns + target_answer_columns

# %%
preds

# %%
submission = ids.join(preds)

# %%
submission.to_csv("submission.csv")
